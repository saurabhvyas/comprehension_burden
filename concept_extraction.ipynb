# %%
import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords

#import sys  

#reload(sys)  
#sys.setdefaultencoding('utf8')

# %%
stop = set(stopwords.words('english'))
stop_list = list(stop)
def remove_stop_words( text ) :
             
         querywords = text.split()
     
         resultwords  = [word for word in querywords if word.lower() not in 
     stop_list]
         result = ' '.join(resultwords)
         print result

# %%
text2 = """ Early computer systems allowed only one program to be executed at a
time. This program had complete control of the system and had access to
all the system's resources. In contrast, current-day computer systems allow
multiple programs to be loaded into memory and executed concurrently.
This evolution required firmer control and more compartmentalization of the
various programs; and these needs resulted in the notion of a process/ which is
a program in execution. A process is the unit of work in a modern time-sharing
system.  """

# %%
text = '''We have looked at the operating system's role from the views of the user
and of the system. How, though, can we define what an operating system
is? In general, we have no completely adequate definition of an operating
system. Operating systems exist because they offer a reasonable way to solve
the problem of creating a usable computing system. The fundamental goal
of computer systems is to execute user programs and to make solving user
problems easier. Toward this goal, computer hardware is constructed. Since
bare hardware alone is not particularly easy to use, application programs are developed. These programs require certain common operations, such as those
controlling the I/O devices. The common functions of controlling and allocating
resources are then brought together into one piece of software: the operating
system.
In addition, we have no universally accepted definition of what is part of the
operating system. A simple viewpoint is that it includes everything a vendor
ships when you order "the operating system." The features included, however,
vary greatly across systems. Some systems take up less than 1 megabyte of
space and lack even a full-screen editor, whereas others require gigabytes of
space and are entirely based on graphical windowing systems. (A kilobyte, or
KB, is 1,024 bytes; a megabyte, or MB, is l,024 2 bytes; and a gigabyte, or GB, is
l,024 3 bytes. Computer manufacturers often round off these numbers and say
that a megabyte is 1 million bytes and a gigabyte is 1 billion bytes.) A more
common definition is that the operating system is the one program running
at all times on the computer (usually called the kernel), with all else being
systems programs and application programs. This last definition is the one
that we generally follow.
The matter of what constitutes an operating system has become increas-
ingly important. In 1998, the United States Department of Justice filed suit
against Microsoft, in essence claiming that Microsoft included too much func-
tionality in its operating systems and thus prevented application vendors from
competing. For example, a web browser was an integral part of the operating
system. As a result, Microsoft was found guilty of using its operating system
monopoly to limit competition.'''

# %%
text=text.decode('utf-8')

# %%
print(text)
# Out:
# We have looked at the operating system's role from the views of the user
# and of the system. How, though, can we define what an operating system
# is? In general, we have no completely adequate definition of an operating
# system. Operating systems exist because they offer a reasonable way to solve
# the problem of creating a usable computing system. The fundamental goal
# of computer systems is to execute user programs and to make solving user
# problems easier. Toward this goal, computer hardware is constructed. Since
# bare hardware alone is not particularly easy to use, application programs are developed. These programs require certain common operations, such as those
# controlling the I/O devices. The common functions of controlling and allocating
# resources are then brought together into one piece of software: the operating
# system.
# In addition, we have no universally accepted definition of what is part of the
# operating system. A simple viewpoint is that it includes everything a vendor
# ships when you order "the operating system." The features included, however,
# vary greatly across systems. Some systems take up less than 1 megabyte of
# space and lack even a full-screen editor, whereas others require gigabytes of
# space and are entirely based on graphical windowing systems. (A kilobyte, or
# KB, is 1,024 bytes; a megabyte, or MB, is l,024 2 bytes; and a gigabyte, or GB, is
# l,024 3 bytes. Computer manufacturers often round off these numbers and say
# that a megabyte is 1 million bytes and a gigabyte is 1 billion bytes.) A more
# common definition is that the operating system is the one program running
# at all times on the computer (usually called the kernel), with all else being
# systems programs and application programs. This last definition is the one
# that we generally follow.
# The matter of what constitutes an operating system has become increas-
# ingly important. In 1998, the United States Department of Justice filed suit
# against Microsoft, in essence claiming that Microsoft included too much func-
# tionality in its operating systems and thus prevented application vendors from
# competing. For example, a web browser was an integral part of the operating
# system. As a result, Microsoft was found guilty of using its operating system
# monopoly to limit competition.

# %%
refined_text = remove_stop_words (text)
# Out:
# looked operating system's role views user system. How, though, define operating system is? general, completely adequate definition operating system. Operating systems exist offer reasonable way solve problem creating usable computing system. fundamental goal computer systems execute user programs make solving user problems easier. Toward goal, computer hardware constructed. Since bare hardware alone particularly easy use, application programs developed. programs require certain common operations, controlling I/O devices. common functions controlling allocating resources brought together one piece software: operating system. addition, universally accepted definition part operating system. simple viewpoint includes everything vendor ships order "the operating system." features included, however, vary greatly across systems. systems take less 1 megabyte space lack even full-screen editor, whereas others require gigabytes space entirely based graphical windowing systems. (A kilobyte, KB, 1,024 bytes; megabyte, MB, l,024 2 bytes; gigabyte, GB, l,024 3 bytes. Computer manufacturers often round numbers say megabyte 1 million bytes gigabyte 1 billion bytes.) common definition operating system one program running times computer (usually called kernel), else systems programs application programs. last definition one generally follow. matter constitutes operating system become increas- ingly important. 1998, United States Department Justice filed suit Microsoft, essence claiming Microsoft included much func- tionality operating systems thus prevented application vendors competing. example, web browser integral part operating system. result, Microsoft found guilty using operating system monopoly limit competition.

# %%
result2 = pos_tag(word_tokenize(text))

# %%
result2
# Out:
# [(u'We', 'PRP'),
#  (u'have', 'VBP'),
#  (u'looked', 'VBN'),
#  (u'at', 'IN'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u"'s", 'POS'),
#  (u'role', 'NN'),
#  (u'from', 'IN'),
#  (u'the', 'DT'),
#  (u'views', 'NNS'),
#  (u'of', 'IN'),
#  (u'the', 'DT'),
#  (u'user', 'NN'),
#  (u'and', 'CC'),
#  (u'of', 'IN'),
#  (u'the', 'DT'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'How', 'NNP'),
#  (u',', ','),
#  (u'though', 'RB'),
#  (u',', ','),
#  (u'can', 'MD'),
#  (u'we', 'PRP'),
#  (u'define', 'VB'),
#  (u'what', 'WP'),
#  (u'an', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'is', 'VBZ'),
#  (u'?', '.'),
#  (u'In', 'IN'),
#  (u'general', 'JJ'),
#  (u',', ','),
#  (u'we', 'PRP'),
#  (u'have', 'VBP'),
#  (u'no', 'DT'),
#  (u'completely', 'RB'),
#  (u'adequate', 'JJ'),
#  (u'definition', 'NN'),
#  (u'of', 'IN'),
#  (u'an', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'Operating', 'VBG'),
#  (u'systems', 'NNS'),
#  (u'exist', 'VBP'),
#  (u'because', 'IN'),
#  (u'they', 'PRP'),
#  (u'offer', 'VBP'),
#  (u'a', 'DT'),
#  (u'reasonable', 'JJ'),
#  (u'way', 'NN'),
#  (u'to', 'TO'),
#  (u'solve', 'VB'),
#  (u'the', 'DT'),
#  (u'problem', 'NN'),
#  (u'of', 'IN'),
#  (u'creating', 'VBG'),
#  (u'a', 'DT'),
#  (u'usable', 'JJ'),
#  (u'computing', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'The', 'DT'),
#  (u'fundamental', 'JJ'),
#  (u'goal', 'NN'),
#  (u'of', 'IN'),
#  (u'computer', 'NN'),
#  (u'systems', 'NNS'),
#  (u'is', 'VBZ'),
#  (u'to', 'TO'),
#  (u'execute', 'VB'),
#  (u'user', 'JJ'),
#  (u'programs', 'NNS'),
#  (u'and', 'CC'),
#  (u'to', 'TO'),
#  (u'make', 'VB'),
#  (u'solving', 'VBG'),
#  (u'user', 'JJ'),
#  (u'problems', 'NNS'),
#  (u'easier', 'RBR'),
#  (u'.', '.'),
#  (u'Toward', 'VB'),
#  (u'this', 'DT'),
#  (u'goal', 'NN'),
#  (u',', ','),
#  (u'computer', 'NN'),
#  (u'hardware', 'NN'),
#  (u'is', 'VBZ'),
#  (u'constructed', 'VBN'),
#  (u'.', '.'),
#  (u'Since', 'IN'),
#  (u'bare', 'NN'),
#  (u'hardware', 'NN'),
#  (u'alone', 'RB'),
#  (u'is', 'VBZ'),
#  (u'not', 'RB'),
#  (u'particularly', 'RB'),
#  (u'easy', 'JJ'),
#  (u'to', 'TO'),
#  (u'use', 'VB'),
#  (u',', ','),
#  (u'application', 'NN'),
#  (u'programs', 'NNS'),
#  (u'are', 'VBP'),
#  (u'developed', 'VBN'),
#  (u'.', '.'),
#  (u'These', 'DT'),
#  (u'programs', 'NNS'),
#  (u'require', 'VBP'),
#  (u'certain', 'JJ'),
#  (u'common', 'JJ'),
#  (u'operations', 'NNS'),
#  (u',', ','),
#  (u'such', 'JJ'),
#  (u'as', 'IN'),
#  (u'those', 'DT'),
#  (u'controlling', 'VBG'),
#  (u'the', 'DT'),
#  (u'I/O', 'NNP'),
#  (u'devices', 'NNS'),
#  (u'.', '.'),
#  (u'The', 'DT'),
#  (u'common', 'JJ'),
#  (u'functions', 'NNS'),
#  (u'of', 'IN'),
#  (u'controlling', 'VBG'),
#  (u'and', 'CC'),
#  (u'allocating', 'JJ'),
#  (u'resources', 'NNS'),
#  (u'are', 'VBP'),
#  (u'then', 'RB'),
#  (u'brought', 'VBN'),
#  (u'together', 'RB'),
#  (u'into', 'IN'),
#  (u'one', 'CD'),
#  (u'piece', 'NN'),
#  (u'of', 'IN'),
#  (u'software', 'NN'),
#  (u':', ':'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'In', 'IN'),
#  (u'addition', 'NN'),
#  (u',', ','),
#  (u'we', 'PRP'),
#  (u'have', 'VBP'),
#  (u'no', 'DT'),
#  (u'universally', 'RB'),
#  (u'accepted', 'VBN'),
#  (u'definition', 'NN'),
#  (u'of', 'IN'),
#  (u'what', 'WP'),
#  (u'is', 'VBZ'),
#  (u'part', 'NN'),
#  (u'of', 'IN'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'A', 'DT'),
#  (u'simple', 'JJ'),
#  (u'viewpoint', 'NN'),
#  (u'is', 'VBZ'),
#  (u'that', 'IN'),
#  (u'it', 'PRP'),
#  (u'includes', 'VBZ'),
#  (u'everything', 'NN'),
#  (u'a', 'DT'),
#  (u'vendor', 'NN'),
#  (u'ships', 'NNS'),
#  (u'when', 'WRB'),
#  (u'you', 'PRP'),
#  (u'order', 'NN'),
#  (u'``', '``'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u"''", "''"),
#  (u'The', 'DT'),
#  (u'features', 'NNS'),
#  (u'included', 'VBD'),
#  (u',', ','),
#  (u'however', 'RB'),
#  (u',', ','),
#  (u'vary', 'VBP'),
#  (u'greatly', 'RB'),
#  (u'across', 'IN'),
#  (u'systems', 'NNS'),
#  (u'.', '.'),
#  (u'Some', 'DT'),
#  (u'systems', 'NNS'),
#  (u'take', 'VBP'),
#  (u'up', 'RP'),
#  (u'less', 'JJR'),
#  (u'than', 'IN'),
#  (u'1', 'CD'),
#  (u'megabyte', 'NN'),
#  (u'of', 'IN'),
#  (u'space', 'NN'),
#  (u'and', 'CC'),
#  (u'lack', 'VB'),
#  (u'even', 'RB'),
#  (u'a', 'DT'),
#  (u'full-screen', 'JJ'),
#  (u'editor', 'NN'),
#  (u',', ','),
#  (u'whereas', 'IN'),
#  (u'others', 'NNS'),
#  (u'require', 'VBP'),
#  (u'gigabytes', 'NNS'),
#  (u'of', 'IN'),
#  (u'space', 'NN'),
#  (u'and', 'CC'),
#  (u'are', 'VBP'),
#  (u'entirely', 'RB'),
#  (u'based', 'VBN'),
#  (u'on', 'IN'),
#  (u'graphical', 'JJ'),
#  (u'windowing', 'VBG'),
#  (u'systems', 'NNS'),
#  (u'.', '.'),
#  (u'(', '('),
#  (u'A', 'DT'),
#  (u'kilobyte', 'NN'),
#  (u',', ','),
#  (u'or', 'CC'),
#  (u'KB', 'NNP'),
#  (u',', ','),
#  (u'is', 'VBZ'),
#  (u'1,024', 'CD'),
#  (u'bytes', 'NNS'),
#  (u';', ':'),
#  (u'a', 'DT'),
#  (u'megabyte', 'NN'),
#  (u',', ','),
#  (u'or', 'CC'),
#  (u'MB', 'NNP'),
#  (u',', ','),
#  (u'is', 'VBZ'),
#  (u'l,024', 'JJ'),
#  (u'2', 'CD'),
#  (u'bytes', 'NNS'),
#  (u';', ':'),
#  (u'and', 'CC'),
#  (u'a', 'DT'),
#  (u'gigabyte', 'NN'),
#  (u',', ','),
#  (u'or', 'CC'),
#  (u'GB', 'NNP'),
#  (u',', ','),
#  (u'is', 'VBZ'),
#  (u'l,024', 'JJ'),
#  (u'3', 'CD'),
#  (u'bytes', 'NNS'),
#  (u'.', '.'),
#  (u'Computer', 'NNP'),
#  (u'manufacturers', 'NNS'),
#  (u'often', 'RB'),
#  (u'round', 'VBP'),
#  (u'off', 'IN'),
#  (u'these', 'DT'),
#  (u'numbers', 'NNS'),
#  (u'and', 'CC'),
#  (u'say', 'VBP'),
#  (u'that', 'IN'),
#  (u'a', 'DT'),
#  (u'megabyte', 'NN'),
#  (u'is', 'VBZ'),
#  (u'1', 'CD'),
#  (u'million', 'CD'),
#  (u'bytes', 'NNS'),
#  (u'and', 'CC'),
#  (u'a', 'DT'),
#  (u'gigabyte', 'NN'),
#  (u'is', 'VBZ'),
#  (u'1', 'CD'),
#  (u'billion', 'CD'),
#  (u'bytes', 'NNS'),
#  (u'.', '.'),
#  (u')', ')'),
#  (u'A', 'DT'),
#  (u'more', 'RBR'),
#  (u'common', 'JJ'),
#  (u'definition', 'NN'),
#  (u'is', 'VBZ'),
#  (u'that', 'IN'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'is', 'VBZ'),
#  (u'the', 'DT'),
#  (u'one', 'NN'),
#  (u'program', 'NN'),
#  (u'running', 'NN'),
#  (u'at', 'IN'),
#  (u'all', 'DT'),
#  (u'times', 'NNS'),
#  (u'on', 'IN'),
#  (u'the', 'DT'),
#  (u'computer', 'NN'),
#  (u'(', '('),
#  (u'usually', 'RB'),
#  (u'called', 'VBN'),
#  (u'the', 'DT'),
#  (u'kernel', 'NN'),
#  (u')', ')'),
#  (u',', ','),
#  (u'with', 'IN'),
#  (u'all', 'DT'),
#  (u'else', 'RB'),
#  (u'being', 'VBG'),
#  (u'systems', 'NNS'),
#  (u'programs', 'NNS'),
#  (u'and', 'CC'),
#  (u'application', 'NN'),
#  (u'programs', 'NNS'),
#  (u'.', '.'),
#  (u'This', 'DT'),
#  (u'last', 'JJ'),
#  (u'definition', 'NN'),
#  (u'is', 'VBZ'),
#  (u'the', 'DT'),
#  (u'one', 'NN'),
#  (u'that', 'WDT'),
#  (u'we', 'PRP'),
#  (u'generally', 'RB'),
#  (u'follow', 'VBP'),
#  (u'.', '.'),
#  (u'The', 'DT'),
#  (u'matter', 'NN'),
#  (u'of', 'IN'),
#  (u'what', 'WP'),
#  (u'constitutes', 'VBZ'),
#  (u'an', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'has', 'VBZ'),
#  (u'become', 'VBN'),
#  (u'increas-', 'JJ'),
#  (u'ingly', 'RB'),
#  (u'important', 'JJ'),
#  (u'.', '.'),
#  (u'In', 'IN'),
#  (u'1998', 'CD'),
#  (u',', ','),
#  (u'the', 'DT'),
#  (u'United', 'NNP'),
#  (u'States', 'NNPS'),
#  (u'Department', 'NNP'),
#  (u'of', 'IN'),
#  (u'Justice', 'NNP'),
#  (u'filed', 'VBD'),
#  (u'suit', 'NN'),
#  (u'against', 'IN'),
#  (u'Microsoft', 'NNP'),
#  (u',', ','),
#  (u'in', 'IN'),
#  (u'essence', 'NN'),
#  (u'claiming', 'NN'),
#  (u'that', 'WDT'),
#  (u'Microsoft', 'NNP'),
#  (u'included', 'VBD'),
#  (u'too', 'RB'),
#  (u'much', 'JJ'),
#  (u'func-', 'JJ'),
#  (u'tionality', 'NN'),
#  (u'in', 'IN'),
#  (u'its', 'PRP$'),
#  (u'operating', 'NN'),
#  (u'systems', 'NNS'),
#  (u'and', 'CC'),
#  (u'thus', 'RB'),
#  (u'prevented', 'VBN'),
#  (u'application', 'NN'),
#  (u'vendors', 'NNS'),
#  (u'from', 'IN'),
#  (u'competing', 'VBG'),
#  (u'.', '.'),
#  (u'For', 'IN'),
#  (u'example', 'NN'),
#  (u',', ','),
#  (u'a', 'DT'),
#  (u'web', 'NN'),
#  (u'browser', 'NN'),
#  (u'was', 'VBD'),
#  (u'an', 'DT'),
#  (u'integral', 'JJ'),
#  (u'part', 'NN'),
#  (u'of', 'IN'),
#  (u'the', 'DT'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'.', '.'),
#  (u'As', 'IN'),
#  (u'a', 'DT'),
#  (u'result', 'NN'),
#  (u',', ','),
#  (u'Microsoft', 'NNP'),
#  (u'was', 'VBD'),
#  (u'found', 'VBN'),
#  (u'guilty', 'JJ'),
#  (u'of', 'IN'),
#  (u'using', 'VBG'),
#  (u'its', 'PRP$'),
#  (u'operating', 'NN'),
#  (u'system', 'NN'),
#  (u'monopoly', 'NN'),
#  (u'to', 'TO'),
#  (u'limit', 'VB'),
#  (u'competition', 'NN'),
#  (u'.', '.')]

# %%
pattern = """
        P2: {<JJ>* <NN>+ }
        
        

    """
parser = nltk.RegexpParser(pattern) 
result3 = parser.parse(result2)

# %%
print(result3)
# Out:
# (S
#   We/PRP
#   have/VBP
#   looked/VBN
#   at/IN
#   the/DT
#   (P2 operating/NN system/NN)
#   's/POS
#   (P2 role/NN)
#   from/IN
#   the/DT
#   views/NNS
#   of/IN
#   the/DT
#   (P2 user/NN)
#   and/CC
#   of/IN
#   the/DT
#   (P2 system/NN)
#   ./.
#   How/NNP
#   ,/,
#   though/RB
#   ,/,
#   can/MD
#   we/PRP
#   define/VB
#   what/WP
#   an/DT
#   (P2 operating/NN system/NN)
#   is/VBZ
#   ?/.
#   In/IN
#   general/JJ
#   ,/,
#   we/PRP
#   have/VBP
#   no/DT
#   completely/RB
#   (P2 adequate/JJ definition/NN)
#   of/IN
#   an/DT
#   (P2 operating/NN system/NN)
#   ./.
#   Operating/VBG
#   systems/NNS
#   exist/VBP
#   because/IN
#   they/PRP
#   offer/VBP
#   a/DT
#   (P2 reasonable/JJ way/NN)
#   to/TO
#   solve/VB
#   the/DT
#   (P2 problem/NN)
#   of/IN
#   creating/VBG
#   a/DT
#   (P2 usable/JJ computing/NN system/NN)
#   ./.
#   The/DT
#   (P2 fundamental/JJ goal/NN)
#   of/IN
#   (P2 computer/NN)
#   systems/NNS
#   is/VBZ
#   to/TO
#   execute/VB
#   user/JJ
#   programs/NNS
#   and/CC
#   to/TO
#   make/VB
#   solving/VBG
#   user/JJ
#   problems/NNS
#   easier/RBR
#   ./.
#   Toward/VB
#   this/DT
#   (P2 goal/NN)
#   ,/,
#   (P2 computer/NN hardware/NN)
#   is/VBZ
#   constructed/VBN
#   ./.
#   Since/IN
#   (P2 bare/NN hardware/NN)
#   alone/RB
#   is/VBZ
#   not/RB
#   particularly/RB
#   easy/JJ
#   to/TO
#   use/VB
#   ,/,
#   (P2 application/NN)
#   programs/NNS
#   are/VBP
#   developed/VBN
#   ./.
#   These/DT
#   programs/NNS
#   require/VBP
#   certain/JJ
#   common/JJ
#   operations/NNS
#   ,/,
#   such/JJ
#   as/IN
#   those/DT
#   controlling/VBG
#   the/DT
#   I/O/NNP
#   devices/NNS
#   ./.
#   The/DT
#   common/JJ
#   functions/NNS
#   of/IN
#   controlling/VBG
#   and/CC
#   allocating/JJ
#   resources/NNS
#   are/VBP
#   then/RB
#   brought/VBN
#   together/RB
#   into/IN
#   one/CD
#   (P2 piece/NN)
#   of/IN
#   (P2 software/NN)
#   :/:
#   the/DT
#   (P2 operating/NN system/NN)
#   ./.
#   In/IN
#   (P2 addition/NN)
#   ,/,
#   we/PRP
#   have/VBP
#   no/DT
#   universally/RB
#   accepted/VBN
#   (P2 definition/NN)
#   of/IN
#   what/WP
#   is/VBZ
#   (P2 part/NN)
#   of/IN
#   the/DT
#   (P2 operating/NN system/NN)
#   ./.
#   A/DT
#   (P2 simple/JJ viewpoint/NN)
#   is/VBZ
#   that/IN
#   it/PRP
#   includes/VBZ
#   (P2 everything/NN)
#   a/DT
#   (P2 vendor/NN)
#   ships/NNS
#   when/WRB
#   you/PRP
#   (P2 order/NN)
#   ``/``
#   the/DT
#   (P2 operating/NN system/NN)
#   ./.
#   ''/''
#   The/DT
#   features/NNS
#   included/VBD
#   ,/,
#   however/RB
#   ,/,
#   vary/VBP
#   greatly/RB
#   across/IN
#   systems/NNS
#   ./.
#   Some/DT
#   systems/NNS
#   take/VBP
#   up/RP
#   less/JJR
#   than/IN
#   1/CD
#   (P2 megabyte/NN)
#   of/IN
#   (P2 space/NN)
#   and/CC
#   lack/VB
#   even/RB
#   a/DT
#   (P2 full-screen/JJ editor/NN)
#   ,/,
#   whereas/IN
#   others/NNS
#   require/VBP
#   gigabytes/NNS
#   of/IN
#   (P2 space/NN)
#   and/CC
#   are/VBP
#   entirely/RB
#   based/VBN
#   on/IN
#   graphical/JJ
#   windowing/VBG
#   systems/NNS
#   ./.
#   (/(
#   A/DT
#   (P2 kilobyte/NN)
#   ,/,
#   or/CC
#   KB/NNP
#   ,/,
#   is/VBZ
#   1,024/CD
#   bytes/NNS
#   ;/:
#   a/DT
#   (P2 megabyte/NN)
#   ,/,
#   or/CC
#   MB/NNP
#   ,/,
#   is/VBZ
#   l,024/JJ
#   2/CD
#   bytes/NNS
#   ;/:
#   and/CC
#   a/DT
#   (P2 gigabyte/NN)
#   ,/,
#   or/CC
#   GB/NNP
#   ,/,
#   is/VBZ
#   l,024/JJ
#   3/CD
#   bytes/NNS
#   ./.
#   Computer/NNP
#   manufacturers/NNS
#   often/RB
#   round/VBP
#   off/IN
#   these/DT
#   numbers/NNS
#   and/CC
#   say/VBP
#   that/IN
#   a/DT
#   (P2 megabyte/NN)
#   is/VBZ
#   1/CD
#   million/CD
#   bytes/NNS
#   and/CC
#   a/DT
#   (P2 gigabyte/NN)
#   is/VBZ
#   1/CD
#   billion/CD
#   bytes/NNS
#   ./.
#   )/)
#   A/DT
#   more/RBR
#   (P2 common/JJ definition/NN)
#   is/VBZ
#   that/IN
#   the/DT
#   (P2 operating/NN system/NN)
#   is/VBZ
#   the/DT
#   (P2 one/NN program/NN running/NN)
#   at/IN
#   all/DT
#   times/NNS
#   on/IN
#   the/DT
#   (P2 computer/NN)
#   (/(
#   usually/RB
#   called/VBN
#   the/DT
#   (P2 kernel/NN)
#   )/)
#   ,/,
#   with/IN
#   all/DT
#   else/RB
#   being/VBG
#   systems/NNS
#   programs/NNS
#   and/CC
#   (P2 application/NN)
#   programs/NNS
#   ./.
#   This/DT
#   (P2 last/JJ definition/NN)
#   is/VBZ
#   the/DT
#   (P2 one/NN)
#   that/WDT
#   we/PRP
#   generally/RB
#   follow/VBP
#   ./.
#   The/DT
#   (P2 matter/NN)
#   of/IN
#   what/WP
#   constitutes/VBZ
#   an/DT
#   (P2 operating/NN system/NN)
#   has/VBZ
#   become/VBN
#   increas-/JJ
#   ingly/RB
#   important/JJ
#   ./.
#   In/IN
#   1998/CD
#   ,/,
#   the/DT
#   United/NNP
#   States/NNPS
#   Department/NNP
#   of/IN
#   Justice/NNP
#   filed/VBD
#   (P2 suit/NN)
#   against/IN
#   Microsoft/NNP
#   ,/,
#   in/IN
#   (P2 essence/NN claiming/NN)
#   that/WDT
#   Microsoft/NNP
#   included/VBD
#   too/RB
#   (P2 much/JJ func-/JJ tionality/NN)
#   in/IN
#   its/PRP$
#   (P2 operating/NN)
#   systems/NNS
#   and/CC
#   thus/RB
#   prevented/VBN
#   (P2 application/NN)
#   vendors/NNS
#   from/IN
#   competing/VBG
#   ./.
#   For/IN
#   (P2 example/NN)
#   ,/,
#   a/DT
#   (P2 web/NN browser/NN)
#   was/VBD
#   an/DT
#   (P2 integral/JJ part/NN)
#   of/IN
#   the/DT
#   (P2 operating/NN system/NN)
#   ./.
#   As/IN
#   a/DT
#   (P2 result/NN)
#   ,/,
#   Microsoft/NNP
#   was/VBD
#   found/VBN
#   guilty/JJ
#   of/IN
#   using/VBG
#   its/PRP$
#   (P2 operating/NN system/NN monopoly/NN)
#   to/TO
#   limit/VB
#   (P2 competition/NN)
#   ./.)

# %%
for st in result3.subtrees(filter = lambda x: x.label() == "P2") :
 print(st)
# Out:
# (P2 operating/NN system/NN)
# (P2 role/NN)
# (P2 user/NN)
# (P2 system/NN)
# (P2 operating/NN system/NN)
# (P2 adequate/JJ definition/NN)
# (P2 operating/NN system/NN)
# (P2 reasonable/JJ way/NN)
# (P2 problem/NN)
# (P2 usable/JJ computing/NN system/NN)
# (P2 fundamental/JJ goal/NN)
# (P2 computer/NN)
# (P2 goal/NN)
# (P2 computer/NN hardware/NN)
# (P2 bare/NN hardware/NN)
# (P2 application/NN)
# (P2 piece/NN)
# (P2 software/NN)
# (P2 operating/NN system/NN)
# (P2 addition/NN)
# (P2 definition/NN)
# (P2 part/NN)
# (P2 operating/NN system/NN)
# (P2 simple/JJ viewpoint/NN)
# (P2 everything/NN)
# (P2 vendor/NN)
# (P2 order/NN)
# (P2 operating/NN system/NN)
# (P2 megabyte/NN)
# (P2 space/NN)
# (P2 full-screen/JJ editor/NN)
# (P2 space/NN)
# (P2 kilobyte/NN)
# (P2 megabyte/NN)
# (P2 gigabyte/NN)
# (P2 megabyte/NN)
# (P2 gigabyte/NN)
# (P2 common/JJ definition/NN)
# (P2 operating/NN system/NN)
# (P2 one/NN program/NN running/NN)
# (P2 computer/NN)
# (P2 kernel/NN)
# (P2 application/NN)
# (P2 last/JJ definition/NN)
# (P2 one/NN)
# (P2 matter/NN)
# (P2 operating/NN system/NN)
# (P2 suit/NN)
# (P2 essence/NN claiming/NN)
# (P2 much/JJ func-/JJ tionality/NN)
# (P2 operating/NN)
# (P2 application/NN)
# (P2 example/NN)
# (P2 web/NN browser/NN)
# (P2 integral/JJ part/NN)
# (P2 operating/NN system/NN)
# (P2 result/NN)
# (P2 operating/NN system/NN monopoly/NN)
# (P2 competition/NN)

# %%
concepts = []

for subtree in result3.subtrees(filter=lambda t: t.label() == 'P2'):
    concepts.append(" ".join([a for (a,b) in subtree.leaves()]))

# %%
concepts
# Out:
# [u'operating system',
#  u'role',
#  u'user',
#  u'system',
#  u'operating system',
#  u'adequate definition',
#  u'operating system',
#  u'reasonable way',
#  u'problem',
#  u'usable computing system',
#  u'fundamental goal',
#  u'computer',
#  u'goal',
#  u'computer hardware',
#  u'bare hardware',
#  u'application',
#  u'piece',
#  u'software',
#  u'operating system',
#  u'addition',
#  u'definition',
#  u'part',
#  u'operating system',
#  u'simple viewpoint',
#  u'everything',
#  u'vendor',
#  u'order',
#  u'operating system',
#  u'megabyte',
#  u'space',
#  u'full-screen editor',
#  u'space',
#  u'kilobyte',
#  u'megabyte',
#  u'gigabyte',
#  u'megabyte',
#  u'gigabyte',
#  u'common definition',
#  u'operating system',
#  u'one program running',
#  u'computer',
#  u'kernel',
#  u'application',
#  u'last definition',
#  u'one',
#  u'matter',
#  u'operating system',
#  u'suit',
#  u'essence claiming',
#  u'much func- tionality',
#  u'operating',
#  u'application',
#  u'example',
#  u'web browser',
#  u'integral part',
#  u'operating system',
#  u'result',
#  u'operating system monopoly',
#  u'competition']

# %%
concepts2=list(set(concepts))

# %%
concepts2
# Out:
# [u'kernel',
#  u'kilobyte',
#  u'competition',
#  u'one',
#  u'fundamental goal',
#  u'computer',
#  u'result',
#  u'example',
#  u'goal',
#  u'application',
#  u'addition',
#  u'megabyte',
#  u'system',
#  u'usable computing system',
#  u'everything',
#  u'common definition',
#  u'role',
#  u'integral part',
#  u'suit',
#  u'computer hardware',
#  u'vendor',
#  u'bare hardware',
#  u'part',
#  u'operating',
#  u'user',
#  u'web browser',
#  u'last definition',
#  u'definition',
#  u'adequate definition',
#  u'operating system',
#  u'essence claiming',
#  u'space',
#  u'simple viewpoint',
#  u'gigabyte',
#  u'full-screen editor',
#  u'matter',
#  u'operating system monopoly',
#  u'reasonable way',
#  u'much func- tionality',
#  u'problem',
#  u'piece',
#  u'order',
#  u'one program running',
#  u'software']

# %%
import re
concepts4=[]
for x in concepts2:
    concepts4.append(re.sub('-',' ',x))
concepts4

# this removes - hyphens
# Out:
# [u'kernel',
#  u'kilobyte',
#  u'competition',
#  u'one',
#  u'fundamental goal',
#  u'computer',
#  u'result',
#  u'example',
#  u'goal',
#  u'application',
#  u'addition',
#  u'megabyte',
#  u'system',
#  u'usable computing system',
#  u'everything',
#  u'common definition',
#  u'role',
#  u'integral part',
#  u'suit',
#  u'computer hardware',
#  u'vendor',
#  u'bare hardware',
#  u'part',
#  u'operating',
#  u'user',
#  u'web browser',
#  u'last definition',
#  u'definition',
#  u'adequate definition',
#  u'operating system',
#  u'essence claiming',
#  u'space',
#  u'simple viewpoint',
#  u'gigabyte',
#  u'full screen editor',
#  u'matter',
#  u'operating system monopoly',
#  u'reasonable way',
#  u'much func  tionality',
#  u'problem',
#  u'piece',
#  u'order',
#  u'one program running',
#  u'software']

# %%
import requests

# %%
url_unigram = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=body&order=1';

# %%
url_bigram = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=body&order=2';

# %%
url_trigram = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=body&order=3';

# %%
headers = { 'Ocp-Apim-Subscription-Key':'0578e9cc1c4d4b6596918c873a72d08a2f'};

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
myjson = {
	"queries":
	[
		"this",
		"cpu throughput",
		"this is"
	]
}

# %%
def sort(list,type):
   for item in list:
    print len(item.split()) 
    
    cutoff = -5;
    
    if type=='query':
        cutoff = -6.5
    url_unigram_q = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=query&order=1';
    url_bigram_q = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=query&order=2';
    url_trigram_q = 'https://westus.api.cognitive.microsoft.com/text/weblm/v1.0/calculateJointProbability?model=query&order=3';
        
    if len(item.split()) == 1 :
        
        print"unigram"
        
        myjson={
            
            "queries":[item]
        }
        
        
      #  print(url_unigram)
    
        if type!='query':      
            r = requests.post(url_unigram, json=myjson , headers = headers );
        elif type=='query':
            r = requests.post(url_unigram_q, json=myjson , headers = headers );
    
        result_json = r.json()
        print(result_json['results'][0]['probability'])
        if(result_json['results'][0]['probability'] > cutoff):
            print"greater than threshold need to remove this concept"
            list.remove(item)
        else:
            print("lower than threshold , need to retain this concept")
        # use unigram
        print(r.json());
    elif len(item.split()) == 2:
        
        print"bigram"
        
        myjson={
            
            "queries":[item]
        }
        
        if type!='query':
                
            r = requests.post(url_bigram, json=myjson , headers = headers );
        
        elif type=='query':
            r = requests.post(url_bigram_q, json=myjson , headers = headers );
        
        result_json = r.json()
        print(result_json['results'][0]['probability'])
        if(result_json['results'][0]['probability'] > cutoff):
            print"greater than threshold need to remove this concept"
            list.remove(item)
        else:
            print("lower than threshold , need to retain this concept")
        print(r.json());
        # use bigram
    elif len(item.split()) == 3:
        
        print"trigram"
        
        myjson={
            
            "queries":[item]
        }
            
        if type!='query':
                
            r = requests.post(url_trigram, json=myjson , headers = headers );
        
        elif type=='query':
            r = requests.post(url_trigram_q, json=myjson , headers = headers );
        
        
        result_json = r.json()
        print(result_json['results'][0]['probability'])
        if(result_json['results'][0]['probability'] > cutoff):
            print"greater than threshold need to remove this concept"
            list.remove(item)
        else:
            print("lower than threshold , need to retain this concept")
        
        print(r.json());

# %%
sort(concepts4,"query")
# Out:
# 1
# unigram
# -6.804
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -6.804, u'words': u'kilobyte'}]}
# 2
# bigram
# -8.431
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -8.431, u'words': u'fundamental goal'}]}
# 1
# unigram
# -6.401
# greater than threshold need to remove this concept
# {u'results': [{u'probability': -6.401, u'words': u'megabyte'}]}
# 2
# bigram
# -7.528
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -7.528, u'words': u'common definition'}]}
# 2
# bigram
# -7.258
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -7.258, u'words': u'integral part'}]}
# 2
# bigram
# -6.215
# greater than threshold need to remove this concept
# {u'results': [{u'probability': -6.215, u'words': u'computer hardware'}]}
# 1
# unigram
# -4.759
# greater than threshold need to remove this concept
# {u'results': [{u'probability': -4.759, u'words': u'operating'}]}
# 2
# bigram
# -8.559
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -8.559, u'words': u'last definition'}]}
# 2
# bigram
# -8.206
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -8.206, u'words': u'adequate definition'}]}
# 2
# bigram
# -11.898
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -11.898, u'words': u'essence claiming'}]}
# 2
# bigram
# -11.137
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -11.137, u'words': u'simple viewpoint'}]}
# 3
# trigram
# -9.409
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -9.409, u'words': u'full screen editor'}]}
# 3
# trigram
# -10.28
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -10.28, u'words': u'operating system monopoly'}]}
# 2
# bigram
# -8.468
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -8.468, u'words': u'reasonable way'}]}
# 3
# trigram
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-86-c6a07dd3f5b2> in <module>()
# ----> 1 sort(concepts4,"query")
#
# <ipython-input-82-d516b04824cf> in sort(list, type)
#      76
#      77         elif type=='query':
# ---> 78             r = requests.post(url_trigram_q, json=myjson , headers = headers );
#      79
#      80
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in post(url, data, json, **kwargs)
#     108     """
#     109
# --> 110     return request('post', url, data=data, json=json, **kwargs)
#     111
#     112
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python2.7/dist-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     485                 raise ProxyError(e, request=request)
#     486
# --> 487             raise ConnectionError(e, request=request)
#     488
#     489         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='westus.api.cognitive.microsoft.com', port=443): Max retries exceeded with url: /text/weblm/v1.0/calculateJointProbability?model=query&order=3 (Caused by NewConnectionError('<requests.packages.urllib3.connection.VerifiedHTTPSConnection object at 0x7fb6a9460c10>: Failed to establish a new connection: [Errno 110] Connection timed out',))

# %%
concepts4

# %%
# notes : to further refine make use of glossary at the end of textbook and / or web dictionary and / or frequency of these concepts in other sections and introduce a cutoff

# %%
sort(concepts4, type = 'test')
# Out:
# 1
# unigram
# -7.044
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -7.044, u'words': u'kilobyte'}]}
# 2
# bigram
# -7.643
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -7.643, u'words': u'fundamental goal'}]}
# 1
# unigram
# -4.316
# greater than threshold need to remove this concept
# {u'results': [{u'probability': -4.316, u'words': u'goal'}]}
# 3
# trigram
# -10.228
# lower than threshold , need to retain this concept
# {u'results': [{u'probability': -10.228, u'words': u'usable computing system'}]}
# 2
# bigram
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-93f6f58d2968> in <module>()
# ----> 1 sort(concepts4, type = 'test')
#
# <ipython-input-82-d516b04824cf> in sort(list, type)
#      48         if type!='query':
#      49
# ---> 50             r = requests.post(url_bigram, json=myjson , headers = headers );
#      51
#      52         elif type=='query':
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in post(url, data, json, **kwargs)
#     108     """
#     109
# --> 110     return request('post', url, data=data, json=json, **kwargs)
#     111
#     112
#
# /usr/local/lib/python2.7/dist-packages/requests/api.pyc in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     486         }
#     487         send_kwargs.update(settings)
# --> 488         resp = self.send(prep, **send_kwargs)
#     489
#     490         return resp
#
# /usr/local/lib/python2.7/dist-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     607
#     608         # Send the request
# --> 609         r = adapter.send(request, **kwargs)
#     610
#     611         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python2.7/dist-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/connectionpool.pyc in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/connection.pyc in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/connection.pyc in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /usr/local/lib/python2.7/dist-packages/requests/packages/urllib3/util/connection.pyc in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# /usr/lib/python2.7/socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# KeyboardInterrupt:

# %%
concepts4
# Out:
# [u'user view',
#  u'user intervention',
#  u'individual usability',
#  u'information',
#  u'monitor',
#  u'system',
#  u'print',
#  u'same computer',
#  u'individual user',
#  u'servers\u2014file',
#  u'various hardware',
#  u'resource utilization\u2014',
#  u'fair share',
#  u'operating system',
#  u'minicomputer',
#  u'work',
#  u'single user experience',
#  u'system unit',
#  u'resource utilization']

# %%
concepts6=[]
for x in concepts4:
    concepts6.append(" ".join(x.split()))
    # this removed duplicate spaces

# %%
concepts6
# Out:
# [u'user view',
#  u'user intervention',
#  u'individual usability',
#  u'information',
#  u'monitor',
#  u'system',
#  u'print',
#  u'same computer',
#  u'individual user',
#  u'servers\u2014file',
#  u'various hardware',
#  u'resource utilization\u2014',
#  u'fair share',
#  u'operating system',
#  u'minicomputer',
#  u'work',
#  u'single user experience',
#  u'system unit',
#  u'resource utilization']
